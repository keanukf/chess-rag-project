# %%
import pandas as pd

# Read the CSV file into a DataFrame
local_file_name = 'chess_games.csv'
df = pd.read_csv(local_file_name)

df = df[df['rated'] == True]
len(df)
# Out:
# 8432

# %%
df[df['white_username'] == 'lachesisQ']
# Out:
#                                                url  \
# 3648  https://www.chess.com/game/live/111863569055
# 5554  https://www.chess.com/game/live/115143507579
# 5588  https://www.chess.com/game/live/115401602563
# 5976  https://www.chess.com/game/live/115755000865
# 5978  https://www.chess.com/game/live/115756217885
# 5980  https://www.chess.com/game/live/115757988221
# 5982  https://www.chess.com/game/live/115759225535
# 5984  https://www.chess.com/game/live/115761037057
# 5986  https://www.chess.com/game/live/115762286061
# 5988  https://www.chess.com/game/live/115763424527
# 5990  https://www.chess.com/game/live/115765177577
# 5992  https://www.chess.com/game/live/115765781195
# 5994  https://www.chess.com/game/live/115765867775
# 5996  https://www.chess.com/game/live/115766473567
# 5998  https://www.chess.com/game/live/115767040889
# 8417  https://www.chess.com/game/live/114977372789
#
#                                                     pgn time_control  \
# ...
